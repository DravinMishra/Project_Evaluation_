# %% [markdown]
# *Import Data and Pre-processing*

# %%
import zipfile

# %%
#Importing necessary libraries.
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import zipfile

# Open the zip file in read mode
with zipfile.ZipFile('avocado.csv.zip', 'r') as unzip:
    # Extract the contents of the zip file to the current directory
    unzip.extractall()
    # Read the CSV ile from the extracted zip file
    data=pd.read_csv(unzip.open('avocado.csv'),engine='python')

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
data.shape
# Out:
# (18249, 14)

# %% [markdown]
# *As we can see that there are total 18249 Rows & 14 Columns in dataset.*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# *Here the column unnamed is irrelevent and we need to remove this column*

# %%
data.drop('Unnamed: 0' , axis = 1 , inplace = True)
#del data['unnamed: 0']
data.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# *Checking for null or missing values*

# %%
data.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# *There is no null values in dataset*

# %% [markdown]
# *Checking for unique value*

# %%
data.nunique()
# Out:
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# *Almost all columns have unique values*

# %%
data = data.rename(index = str , columns = {'4046' : "Small" , '4225' : "Laege" , '4770' : "XLarge"})

# %%
data.head(3) #checking for column get renamed or not
# Out:
#          Date  AveragePrice  Total Volume    Small      Laege  XLarge  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany

# %%
# Let's convert the date column for data prediction
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = data['Date'].apply(lambda x:x.month)
data['Day'] = data['Date'].apply(lambda x:x.day)

data.head()
# Out:
#         Date  AveragePrice  Total Volume    Small      Laege  XLarge  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# ...

# %%
# Let's check the visualization of Average Price
import warnings
warnings.filterwarnings('ignore')

sns.set(font_scale=1.5)
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15 , 9))
sns.distplot(a=data.AveragePrice , kde=False , fit = norm)
# Out:
# <Axes: xlabel='AveragePrice'>

# %% [markdown]
# *As we can see that the graph is looks like Normal Distribution Curve*

# %%
plt.figure(figsize = (18,10))
sns.lineplot(x = 'Month' , y = "AveragePrice" , hue = "type" , data = data)
plt.show()

# %% [markdown]
# *Here peak shows in 9th & 10th month*

# %%
region_list = list(data.region.unique())
average_price=[]

for i in region_list :
  x = data[data.region == i]
  region_average = sum(x.AveragePrice)/len(x)
  average_price.append(region_average)

data1 = pd.DataFrame({'region_list' : region_list , 'average_price' : average_price})
new_index = data1.average_price.sort_values(ascending = False).index.values
sorted_data = data1.reindex(new_index)

plt.figure(figsize = (24,10))
ax = sns.barplot(x = sorted_data.region_list , y = sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %% [markdown]
# *Here average price is higher in regions , HalfSpringfield , SanFrancisco , NewYork , Philadelphia , Sacramento , Charlotte.*

# %%
filter1=data.region!='TotalUS'
data1=data[filter1]

region_list=list(data1.region.unique())
average_total_volume=[]

for i in region_list:
    x=data1[data1.region==i]
    average_total_volume.append(sum(x['Total Volume'])/len(x))
data2=pd.DataFrame({'region_list':region_list,'average_total_volume':average_total_volume})

new_index=data2.average_total_volume.sort_values(ascending=False).index.values
sorted_data1=data2.reindex(new_index)

plt.figure(figsize=(22,10))
ax=sns.barplot(x=sorted_data1.region_list,y=sorted_data1.average_total_volume)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average of Total Volume')
plt.title('Average of Total Volume According to Region')
# Out:
# Text(0.5, 1.0, 'Average of Total Volume According to Region')

# %% [markdown]
# *As we can see that West , California , SouthCentral , Northeast , Greatlakes are the countries with most assumption of Avacado.*

# %%
data.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# Small                  float64
# Laege                  float64
# XLarge                 float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %%
# Convert the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Ensure that the 'AveragePrice' column contains only numeric values
data['AveragePrice'] = pd.to_numeric(data['AveragePrice'], errors='coerce')

# Group the data by 'Date' and calculate the mean of 'AveragePrice'
Dates = data.groupby('Date')['AveragePrice'].mean()

# Plot the average price
plt.figure(figsize = (12,8))
Dates.plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# *As we can see that between jul 2018 to jan 2018 ,Average price gets very high.*

# %%
data.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# Small                  float64
# Laege                  float64
# XLarge                 float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   Small         18249 non-null  float64
#  4   Laege         18249 non-null  float64
#  5   XLarge        18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  Month         18249 non-null  int64
#  14  Day           18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(2)
# memory usage: 2.7+ MB

# %%
data.drop(['Date' , 'type' , 'region'] , axis = 1 , inplace = True)

# %%
# prompt: I want to back dropped column in my dataset which I drop in previous cell

import pandas as pd
# To restore the dropped columns, you can use the `concat` function:



# This will merge the dropped columns back into the DataFrame.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   Small         18249 non-null  float64
#  3   Laege         18249 non-null  float64
#  4   XLarge        18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   year          18249 non-null  int64
#  10  Month         18249 non-null  int64
#  11  Day           18249 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 2.3+ MB

# %%
data.corr()
# Out:
#               AveragePrice  Total Volume     Small     Laege    XLarge  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# Small            -0.208317      0.977863  1.000000  0.926110  0.833389
# Laege            -0.172928      0.974181  0.926110  1.000000  0.887855
# XLarge           -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
#
# ...

# %%
#Let us visualize the corelation by using Heatmap for better understanding

plt.figure(figsize=(20,20))
sns.heatmap(data.corr() , annot=True , cmap = 'RdBu' , fmt = '0.02f')
plt.show()

# %% [markdown]
# *As we can that most of the features column are correlated with target column and few are not correlated*

# %% [markdown]
# *That is why let's deal with this by using some features for model prediction.*

# %%
data.columns
# Out:
# Index(['AveragePrice', 'Total Volume', 'Small', 'Laege', 'XLarge',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year',
#        'Month', 'Day'],
#       dtype='object')

# %%
data['year'].nunique()
# Out:
# 4

# %% [markdown]
# *As we can see that year column have only 4 uniue value , So we can create dummy variable for it easily.*

# %%
data.head(2)
# Out:
#    AveragePrice  Total Volume    Small     Laege  XLarge  Total Bags  \
# 0          1.33      64236.62  1036.74  54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28  44638.81   58.33     9505.56
#
#    Small Bags  Large Bags  XLarge Bags  year  Month  Day  Total Volume  \
# 0     8603.62       93.25          0.0  2015     12   27      64236.62
# 1     9408.07       97.49          0.0  2015     12   20      54876.98
#
#      Small     Laege  Total Volume    Small     Laege
# 0  1036.74  54454.85      64236.62  1036.74  54454.85
# 1   674.28  44638.81      54876.98   674.28  44638.81

# %% [markdown]
# ## Feature Engineering for Model building

# %%
# data.plot(kind = 'box' , fontsize=20 , figsize=(20,10) , color = 'Grey')
# plt.xticks(rotation=30 , ha = 'right')
# plt.show()

data.plot(kind='box',fontsize=20,figsize=(20,10),color='grey')
plt.xticks(rotation=30,ha='right')
plt.show()

# %%
outliers=data[['AveragePrice','Small','Laege','XLarge','Total Bags','XLarge Bags']]

# %%
#Using Zscore method for outliers removals

from scipy.stats import zscore
z = np.abs(zscore(outliers))
data_new = data[(z<3).all(axis=1)]
data_new
# Out:
#        AveragePrice  Total Volume    Small      Laege  XLarge  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  year  Month  Day  Total Volume  \
# ...

# %%
data_new.shape
# Out:
# (17738, 18)

# %%
data.shape
# Out:
# (18249, 18)

# %%
# Calculating Data Loss after Outliers removal
Data_Loss = ((18249 - 17738)/18249)*100
Data_Loss
# Out:
# 2.8001534330648252

# %% [markdown]
# *Approximately 3% data lose after removal of Outliers.*

# %%
data_new.skew()
# Out:
# AveragePrice    0.380301
# Total Volume    3.752986
# Small           4.628222
# Laege           4.262080
# XLarge          4.919251
# Total Bags      4.521160
# Small Bags      4.214066
# Large Bags      7.363082
# XLarge Bags     6.063918
# year            0.226281
# Month           0.109722
# Day             0.012325
# Total Volume    3.752986
# Small           4.628222
# Laege           4.262080
# Total Volume    3.752986
# Small           4.628222
# Laege           4.262080
# dtype: float64

# %% [markdown]
# *Some columns have skewness , so we need to remove it for better model performance,*

# %%
# Using power tranformation method for skewness removal.

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
# Separating the features showing skewness and applying the power transformation to it.

data_new[['Total Volume','Small','Laege','XLarge','Total Bags','Small Bags','Large Bags','XLarge',]] = scaler.fit_transform(data_new[['Total Volume','Small','Laege','XLarge','Total Bags','Small Bags','Large Bags','XLarge']].values)

# %%
data_new.skew()  #Now again checking for skewness after removing it.
# Out:
# AveragePrice    0.380301
# Total Volume   -0.006275
# Small          -0.037857
# Laege          -0.044224
# XLarge          0.022830
# Total Bags     -0.017871
# Small Bags     -0.021279
# Large Bags     -0.099351
# XLarge Bags     6.063918
# year            0.226281
# Month           0.109722
# Day             0.012325
# Total Volume   -0.006275
# Small          -0.037857
# Laege          -0.044224
# Total Volume   -0.006275
# Small          -0.037857
# Laege          -0.044224
# dtype: float64

# %%
# Spliting the dataset into features and label
x = data_new.drop('AveragePrice' , axis=1)
y= data_new['AveragePrice']

# %%
x  #this represent features
# Out:
#        Total Volume     Small     Laege    XLarge  Total Bags  Small Bags  \
# 0         -0.081273 -0.660527  0.341073 -0.230768   -0.537291   -0.350584
# 1         -0.152915 -0.779798  0.259825 -0.183627   -0.498142   -0.314792
# 2          0.197185 -0.734570  0.636362  0.014745   -0.566000   -0.377394
# 3          0.012950 -0.635810  0.457445 -0.129789   -0.712117   -0.512918
# 4         -0.185860 -0.687493  0.252497 -0.119158   -0.685442   -0.492602
# ...             ...       ...       ...       ...         ...         ...
# 18244     -0.680885 -0.466150 -0.928695 -1.231412   -0.341590   -0.180485
# 18245     -0.773727 -0.621305 -0.674298 -1.231412   -0.509458   -0.335264
# 18246     -0.777665 -0.621252 -0.782120  0.435277   -0.503348   -0.317204
# 18247     -0.704394 -0.550643 -0.719864  0.434967   -0.434613   -0.254424
# 18248     -0.670088 -0.364355 -0.794825  0.148135   -0.393976   -0.216136
#
#        Large Bags  XLarge Bags  year  Month  Day  Total Volume     Small  \
# ...

# %%
y #This reprentes target variable
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 17738, dtype: float64

# %% [markdown]
# ***Model Selection***

# %%
# Importing the necessary libraries.

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
# Applying standard scaler to data.

ss=StandardScaler()
x_scaled= pd.DataFrame(ss.fit_transform(x), columns=x.columns)

# %%
#Checking for the data after Standardization

x_scaled.head()
# Out:
#    Total Volume     Small     Laege    XLarge  Total Bags  Small Bags  \
# 0     -0.081273 -0.660527  0.341073 -0.230768   -0.537291   -0.350584
# 1     -0.152915 -0.779798  0.259825 -0.183627   -0.498142   -0.314792
# 2      0.197185 -0.734570  0.636362  0.014745   -0.566000   -0.377394
# 3      0.012950 -0.635810  0.457445 -0.129789   -0.712117   -0.512918
# 4     -0.185860 -0.687493  0.252497 -0.119158   -0.685442   -0.492602
#
#    Large Bags  XLarge Bags      year     Month       Day  Total Volume  \
# 0   -0.778034    -0.262931 -1.213431  1.645861  1.289805     -0.081273
# 1   -0.768081    -0.262931 -1.213431  1.645861  0.492047     -0.152915
# 2   -0.755412    -0.262931 -1.213431  1.645861 -0.305711      0.197185
# 3   -0.696084    -0.262931 -1.213431  1.645861 -1.103469      0.012950
# 4   -0.604249    -0.262931 -1.213431  1.363390  1.517736     -0.185860
#
#       Small     Laege  Total Volume     Small     Laege
# 0 -0.660527  0.341073     -0.081273 -0.660527  0.341073
# ...

# %% [markdown]
# *We got the standardized dataset*

# %%
# Checking for the multicolinearity in the dataset using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x_scaled.values, i) for i in range(x_scaled.shape[1])]
vif["Features"]=x_scaled.columns
vif
# Out:
#     vif_Features      Features
# 0            inf  Total Volume
# 1            inf         Small
# 2            inf         Laege
# 3       3.424619        XLarge
# 4      34.487633    Total Bags
# 5      16.543137    Small Bags
# 6       3.471353    Large Bags
# 7       1.209956   XLarge Bags
# 8       1.347580          year
# 9       1.048250         Month
# 10      1.000736           Day
# 11           inf  Total Volume
# 12           inf         Small
# 13           inf         Laege
# 14           inf  Total Volume
# 15           inf         Small
# 16           inf         Laege

# %% [markdown]
# *Multicollinearity only affects the predictor variables that are correlated with one another. As we are interested in a predictor variable in the model that doesn’t suffer from multicollinearity, then multicollinearity isn’t a concern for us.*

# %%
# Checking the Best Accuracy score on random state using linear regression model.

from sklearn.linear_model import  LinearRegression
lr=LinearRegression()

# %%
# Applying Train Test Split on dataset for model building and evaluation.

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

lr.fit(x_train,y_train) # Model training

y_pred=lr.predict(x_test) # Model prediction

# %%
y_pred
# Out:
# array([1.84788146, 1.41880387, 1.35020774, ..., 1.51774169, 1.18866238,
#        0.93705248])

# %%
# Checking the mean square error,mean absolute error,root mean square error for linear regression.

from sklearn import metrics
print('Accuracy Score for Linear Regression:', lr.score(x_train,y_train)*100)
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Accuracy Score for Linear Regression: 49.53826792329335
# MAE: 0.22043034647457396
# MSE: 0.07687761742620973
# RMSE: 0.27726813272752737

# %%
# Checking the Best Accuracy score on random state using Desion tree regressor model.


from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()

dtr.fit(x_train,y_train) # Model training

pred=dtr.predict(x_test) # Model prediction

# %%
pred
# Out:
# array([1.87, 1.01, 1.02, ..., 1.88, 1.16, 1.04])

# %%
# Checking the mean square error,mean absolute error,root mean square error for Decision tree Regressor.

print('Accuracy Score for Decision tree Regressor:', lr.score(x_train,y_train)*100)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Accuracy Score for Decision tree Regressor: 49.53826792329335
# MAE: 0.13912626832018038
# MSE: 0.04456595264937993
# RMSE: 0.21110649599048328

# %%
# Checking the Best Accuracy score on random state using RandomForest regressor model.

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)

# %%
# Checking the mean square error,mean absolute error,root mean square error for Random Forest Regressor.

print('Accuracy Score for Random Forest Regressor:', lr.score(x_train,y_train)*100)
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Accuracy Score for Random Forest Regressor: 49.53826792329335
# MAE: 0.10246547350620067
# MSE: 0.020697162020856814
# RMSE: 0.1438650827020122

# %%
# Checking the Best Accuracy score on random state using SVR model.

from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)

# %%
pred_svr
# Out:
# array([1.44754671, 1.4422474 , 1.44429509, ..., 1.44498123, 1.43755175,
#        1.42894932])

# %%
# Checking the mean square error,mean absolute error,root mean square error for SVR.

print('Accuracy Score for SVR:', lr.score(x_train,y_train)*100)
print('MAE:', metrics.mean_absolute_error(y_test, pred_svr))
print('MSE:', metrics.mean_squared_error(y_test, pred_svr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_svr)))
# Out:
# Accuracy Score for SVR: 49.53826792329335
# MAE: 0.29785570329229116
# MSE: 0.13721424059442472
# RMSE: 0.37042440604585536

# %%
# Model building using KNeighbors Regressor Algorithm.

from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn import metrics
knn=KNN()
knn.fit(x_train,y_train) # Model training
y_pred=knn.predict(x_test) # Model prediction
y_pred
# Out:
# array([1.824, 1.424, 1.266, ..., 1.86 , 1.02 , 1.106])

# %%
# Checking the mean square error,mean absolute error,root mean square error for KNN.

print('Accuracy Score for KNN:', lr.score(x_train,y_train)*100)
print('MAE:', metrics.mean_absolute_error(y_test, pred_svr))
print('MSE:', metrics.mean_squared_error(y_test, pred_svr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_svr)))
# Out:
# Accuracy Score for KNN: 49.53826792329335
# MAE: 0.29785570329229116
# MSE: 0.13721424059442472
# RMSE: 0.37042440604585536

# %% [markdown]
# After checking each model's  mean square error,mean absolute error,root mean square error we got the least RMSE score for RandomForest Regressor model,
# so it should be the best fit model but before that let's check the cross validation score for each model. *italicized text*

# %% [markdown]
# **Cross-Validation** check for each model

# %%
from sklearn.model_selection import cross_val_score

c_v_s = cross_val_score(lr,x,y,cv=8)
print('Cross Validation Score for Linear Regression is - ' , c_v_s.mean())
# Out:
# Cross Validation Score for Linear Regression is -  0.007609058191729828

# %%
c_v_s = cross_val_score(dtr , x , y , cv=8)
print('Cross Validation Score for Decision Tree Regression is - ' , c_v_s.mean())
# Out:
# Cross Validation Score for Decision Tree is -  -0.4949576067339591

# %%
c_v_s = cross_val_score(rf , x , y , cv=8)
print('Cross Validation Score for Random Forest Regression is - ' , c_v_s.mean())
# Out:
# Cross Validation Score for Random Forest Regression is -  0.11444994777057034

# %%
c_v_s = cross_val_score(svr , x , y , cv=8)
print('Cross Validation Score for Support Vector Regression is - ' , c_v_s.mean())
# Out:
# Cross Validation Score for Support Vector Regression is -  -1.0464152594903187

# %% [markdown]
# *As we can see from above output, the best cross validation score for Random Forest Regressor model so it will be the best fit for modeland we will further proceed with it.*

# %% [markdown]
# # **Hyper Parameter Tuning**

# %%
from sklearn.linear_model import Lasso , Ridge
from sklearn.model_selection import GridSearchCV

# %%
# Checking the Lasso's r2_score , mse , mae , rmse.
params = {'alpha' : [0.001 , 0.01 , 0.1 , 1.0 , 10], 'random_state' : list(range(0,100))}
LR = Lasso()
reg = GridSearchCV(LR , params)
reg.fit(x_train , y_train)
print(reg.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}
# {'alpha': 0.001, 'random_state': 0}

# %%
LR = Lasso(alpha=1 , random_state = 0)
LR.fit(x_train , y_train)
pred = LR.predict(x_test)
print('r2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# r2_score: 0.02429683684824302
# mse: 0.14932275755426785
# mae: 0.31465555239499715
# rmse: 0.38642302927525923
# r2_score: 0.02429683684824302
# mse: 0.14932275755426785
# mae: 0.31465555239499715
# rmse: 0.38642302927525923

# %%
#Assingning the parameters

params = {'alpha' : [0.01 , 0.1 , 1.0 , 10],
          'selection' : ['cyclic' , 'random'],
          'max_iter' : [3 , 5 , 7 , 9 , 11],
          'tol' : [100 , 1000],
          'fit_intercept' : [True , False],
          'warm_start' : [True , False]
}

# %%
lasso = Lasso(fit_intercept=True)  # Set fit_intercept to True or False
GSV = GridSearchCV(lasso, params, cv=5)

# %%
# Training the model using GridSearchCV
GSV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10],
#                          'fit_intercept': [True, False],
#                          'max_iter': [3, 5, 7, 9, 11],
#                          'selection': ['cyclic', 'random'], 'tol': [100, 1000],
#                          'warm_start': [True, False]})

# %%
# Getting the best parameter.
GSV.best_params_
# Out:
# {'alpha': 0.01,
#  'fit_intercept': True,
#  'max_iter': 3,
#  'selection': 'cyclic',
#  'tol': 100,
#  'warm_start': True}

# %%
Finalize=Lasso(alpha=0.01, fit_intercept=True, max_iter=11, selection="random", tol=1000)
Finalize.fit(x_train,y_train)
pred=Finalize.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 31.709347999987337
# mean_squared_error: 0.10451281554608134
# mean_absolute_error: 0.25542034912088885
# RMSE value: 0.32328441896584087

# %% [markdown]
# *Here we got the mean squared error of 0.1045 which is very less that means that we are very much close to best fit line. Here we got the mean absolute error of almost 0.25% which is very small that means there is not much difference in our true values and predicted values. Here we finally got out best fit model that is Random Forest Regressor.*

# %% [markdown]
# # **Saving the best Model**

# %%
#saving the model using .pkl

import joblib
joblib.dump(Finalize , "Avocado_Price_Prediction.pkl")
# Out:
# ['Avocado_Price_Prediction.pkl']
